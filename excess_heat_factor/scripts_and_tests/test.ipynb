# %%
import xarray as xr

filename = 'ehfheatwaves/tests/climpact2.sampledata.gridded.1991-2010.nc'
ds = xr.open_dataset(filename)
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (lon: 24, lat: 19, time: 7305, nb2: 2)
# Coordinates:
#   * lon        (lon) float32 110.6 112.5 114.4 116.2 ... 148.1 150.0 151.9 153.8
#   * lat        (lat) float32 -10.48 -12.38 -14.29 ... -40.95 -42.86 -44.76
#   * time       (time) datetime64[ns] 1991-01-01 1991-01-02 ... 2010-12-31
# Dimensions without coordinates: nb2
# Data variables:
#     time_bnds  (time, nb2) datetime64[ns] ...
#     tmax       (time, lat, lon) float32 ...
#     tmin       (time, lat, lon) float32 ...
#     precip     (time, lat, lon) float32 ...
# Attributes:
#     history:  Wed Jun 17 11:12:30 2015: ncatted -a ,global,d,, climpact2.samp...

# %%
filename = 'modis_lst_data_cube.nc'
ds2 = xr.open_dataset(filename)
ds2
# Out:
# <xarray.Dataset>
# Dimensions:  (region: 20, date: 12)
# Coordinates:
#   * region   (region) object '102' '106' '107' '109' ... '125' '126' '127' '128'
#   * date     (date) datetime64[ns] 2019-12-03 2019-12-11 ... 2020-02-26
# Data variables:
#     tmax     (region, date) float64 ...
#     tmin     (region, date) float64 ...

# %%
ds.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 ds.close()
#
# NameError: name 'ds' is not defined

# %%
ds2.close()
