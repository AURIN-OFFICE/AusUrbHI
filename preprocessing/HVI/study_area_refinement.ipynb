# %% [markdown]
# # Notebook for study area refinement

# %%
# %matplotlib inline
import geopandas as gpd
import pandas as pd

# %% [markdown]
# ## 1. Load and inspect

# %%
study_area=gpd.read_file("sa1_nsw.shp")
data = gpd.read_file("datasource-AU_Govt_ABS-UoM_AURIN_DB_3_seifa_ieo_aust_sa1_2011.json")
# data=gpd.read_file("<shapefile_name>.shp")

# %%
study_area.plot(figsize=(10,10))
# Out:
# <Axes: >

# %%
study_area.head()
# Out:
#     SA1_MAIN16 SA1_7DIG16 SA2_MAIN16 SA2_5DIG16 SA2_NAME16 SA3_CODE16
# 0  10602111401    1111401  106021114      11114   Maitland      10602  \
# 1  10602111402    1111402  106021114      11114   Maitland      10602
# 2  10602111403    1111403  106021114      11114   Maitland      10602
# 3  10602111404    1111404  106021114      11114   Maitland      10602
# 4  10602111405    1111405  106021114      11114   Maitland      10602
#
#   SA3_NAME16 SA4_CODE16                   SA4_NAME16 GCC_CODE16   GCC_NAME16
# 0   Maitland        106  Hunter Valley exc Newcastle      1RNSW  Rest of NSW  \
# 1   Maitland        106  Hunter Valley exc Newcastle      1RNSW  Rest of NSW
# 2   Maitland        106  Hunter Valley exc Newcastle      1RNSW  Rest of NSW
# 3   Maitland        106  Hunter Valley exc Newcastle      1RNSW  Rest of NSW
# 4   Maitland        106  Hunter Valley exc Newcastle      1RNSW  Rest of NSW
#
#   STE_CODE16       STE_NAME16  AREASQKM16
# ...

# %%
data.plot(figsize=(10,10))
# Out:
# <Axes: >

# %%
data.head()
# Out:
#                                                   id     sa1_code  ur_pop
# 0  seifa_ieo_aust_sa1_2011.fid-492f303f_1877dfa2d...  10101100102     605  \
# 1  seifa_ieo_aust_sa1_2011.fid-492f303f_1877dfa2d...  10101100105     262
# 2  seifa_ieo_aust_sa1_2011.fid-492f303f_1877dfa2d...  10101100106     240
# 3  seifa_ieo_aust_sa1_2011.fid-492f303f_1877dfa2d...  10101100114     362
# 4  seifa_ieo_aust_sa1_2011.fid-492f303f_1877dfa2d...  10101100115     481
#
#    ieo_score   rank  decile  percentile
# 0        934  14387       3          28  \
# 1        869   4619       1           9
# 2        863   4057       1           8
# 3        859   3734       1           8
# 4        920  11809       3          23
#
#                                             geometry
# 0  MULTIPOLYGON (((149.71914 -34.76109, 149.71915...
# 1  MULTIPOLYGON (((149.73377 -34.74382, 149.73385...
# 2  MULTIPOLYGON (((149.71911 -34.75010, 149.71919...
# 3  MULTIPOLYGON (((149.70233 -34.76261, 149.69982...
# ...

# %% [markdown]
# ## 2. Refine

# %%
result = data[data['sa1_code'].isin(study_area['SA1_MAIN16'])]
print(result.head())
result.plot(figsize=(10,10))
result.to_file("result.shp")
# Out:
#                                                     id     sa1_code  ur_pop
# 38   seifa_ieo_aust_sa1_2011.fid-492f303f_1877dfa2d...  10202105020     319  \
# 50   seifa_ieo_aust_sa1_2011.fid-492f303f_1877dfa2d...  11703133429     329
# 85   seifa_ieo_aust_sa1_2011.fid-492f303f_1877dfa2d...  10704114534     458
# 136  seifa_ieo_aust_sa1_2011.fid-492f303f_1877dfa2d...  11103122212     471
# 144  seifa_ieo_aust_sa1_2011.fid-492f303f_1877dfa2d...  11103122213     232
#
#      ieo_score   rank  decile  percentile
# 38         766    360       1           1  \
# 50        1119  45314       9          87
# 85         951  17618       4          34
# 136        999  27174       6          52
# 144       1041  34676       7          66
#
#                                               geometry
# 38   MULTIPOLYGON (((151.56847 -33.17235, 151.56847...
# 50   MULTIPOLYGON (((151.19849 -33.88157, 151.19764...
# 85   MULTIPOLYGON (((150.90807 -34.36774, 150.90873...
# ...
