# %% [markdown]
# # NSW Study Area
#
# This is an exercise to select our study area for the AusUrb-HI Heat Vulnerability Indicator, based on column and attribute names.

# %%
# %matplotlib inline
import geopandas as gpd
import pandas as pd

# %% [markdown]
# Import and inspect shapefiles

# %%
sa1=gpd.read_file("Study Area/sa1_2016/SA1_2016_AUST.shp")

# %%
sa2=gpd.read_file("Study Area/sa2_2016/SA2_2016_AUST.shp")

# %%
sa2
# Out:
#      SA2_MAIN16 SA2_5DIG16                            SA2_NAME16 SA3_CODE16  \
# 0     101021007      11007                             Braidwood      10102
# 1     101021008      11008                               Karabar      10102
# 2     101021009      11009                            Queanbeyan      10102
# 3     101021010      11010                     Queanbeyan - East      10102
# 4     101021011      11011                     Queanbeyan Region      10102
# ...         ...        ...                                   ...        ...
# 2305  901021002      91002               Cocos (Keeling) Islands      90102
# 2306  901031003      91003                            Jervis Bay      90103
# 2307  901041004      91004                        Norfolk Island      90104
# 2308  997979799      99799  Migratory - Offshore - Shipping (OT)      99797
# 2309  999999499      99499                 No usual address (OT)      99999
#
#                                 SA3_NAME16 SA4_CODE16  \
# ...

# %%
sa2.plot(figsize=(10,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## SA2 Areas

# %% [markdown]
# We are looking for SA2 areas that are within Greater Sydney, Tweed Valley, Newcastle-Maitland, Wollongong and Albury areas. We will separate regional and capital areas, then concatenate them in the end.

# %%
sa2_regional = sa2.loc[sa2['SA3_NAME16'].isin(['Tweed Valley', 'Newcastle', 'Maitland', 'Wollongong', 'Albury']), :]

# %%
sa2_regional
# Out:
#     SA2_MAIN16 SA2_5DIG16                          SA2_NAME16 SA3_CODE16  \
# 113  106021114      11114                            Maitland      10602
# 114  106021115      11115                     Maitland - East      10602
# 115  106021116      11116                    Maitland - North      10602
# 116  106021117      11117                     Maitland - West      10602
# 117  106021118      11118           Thornton - Millers Forest      10602
# 145  107041144      11144            Balgownie - Fairy Meadow      10704
# 146  107041145      11145    Corrimal - Tarrawanna - Bellambi      10704
# 147  107041146      11146                Figtree - Keiraville      10704
# 148  107041147      11147                         Helensburgh      10704
# 149  107041148      11148    Thirroul - Austinmer - Coalcliff      10704
# 150  107041150      11150      Woonona - Bulli - Russell Vale      10704
# 151  107041548      11548                   Wollongong - East      10704
# ...

# %%
sa2_capital = sa2.loc[sa2['GCC_NAME16']=='Greater Sydney']

# %%
sa2_capital
# Out:
#     SA2_MAIN16 SA2_5DIG16                   SA2_NAME16 SA3_CODE16  \
# 27   102011028      11028     Avoca Beach - Copacabana      10201
# 28   102011029      11029  Box Head - MacMasters Beach      10201
# 29   102011030      11030              Calga - Kulnura      10201
# 30   102011031      11031          Erina - Green Point      10201
# 31   102011032      11032        Gosford - Springfield      10201
# ..         ...        ...                          ...        ...
# 571  128021537      11537          Royal National Park      12802
# 572  128021538      11538        Sutherland - Kirrawee      12802
# 573  128021607      11607                     Engadine      12802
# 574  128021608      11608         Loftus - Yarrawarrah      12802
# 575  128021609      11609             Woronora Heights      12802
#
#                          SA3_NAME16 SA4_CODE16           SA4_NAME16  \
# 27                          Gosford        102        Central Coast
# ...

# %%
sa2_capital.plot()
# Out:
# <AxesSubplot:>

# %%
sa2_regional.count()
# Out:
# SA2_MAIN16    40
# SA2_5DIG16    40
# SA2_NAME16    40
# SA3_CODE16    40
# SA3_NAME16    40
# SA4_CODE16    40
# SA4_NAME16    40
# GCC_CODE16    40
# GCC_NAME16    40
# STE_CODE16    40
# STE_NAME16    40
# AREASQKM16    40
# geometry      40
# dtype: int64

# %%
sa2_capital.count()
# Out:
# SA2_MAIN16    312
# SA2_5DIG16    312
# SA2_NAME16    312
# SA3_CODE16    312
# SA3_NAME16    312
# SA4_CODE16    312
# SA4_NAME16    312
# GCC_CODE16    312
# GCC_NAME16    312
# STE_CODE16    312
# STE_NAME16    312
# AREASQKM16    312
# geometry      312
# dtype: int64

# %%
sa2_all = pd.concat([sa2_regional, sa2_capital])
sa2_all.count()
# Out:
# SA2_MAIN16    352
# SA2_5DIG16    352
# SA2_NAME16    352
# SA3_CODE16    352
# SA3_NAME16    352
# SA4_CODE16    352
# SA4_NAME16    352
# GCC_CODE16    352
# GCC_NAME16    352
# STE_CODE16    352
# STE_NAME16    352
# AREASQKM16    352
# geometry      352
# dtype: int64

# %%
sa2_all.tail(20)
# Out:
#     SA2_MAIN16 SA2_5DIG16                               SA2_NAME16 SA3_CODE16  \
# 556  127031599      11599                      Lurnea - Cartwright      12703
# 557  127031600      11600                Prestons - Edmondson Park      12703
# 558  127031601      11601                             Warwick Farm      12703
# 559  128011529      11529                      Gymea - Grays Point      12801
# 560  128011530      11530                      Miranda - Yowie Bay      12801
# 561  128011531      11531                   Sylvania - Taren Point      12801
# 562  128011602      11602                                Caringbah      12801
# 563  128011603      11603                          Caringbah South      12801
# 564  128011604      11604            Cronulla - Kurnell - Bundeena      12801
# 565  128011605      11605  Lilli Pilli - Port Hacking - Dolans Bay      12801
# 566  128011606      11606                    Woolaware - Burraneer      12801
# ...

# %%
sa2_all.plot(figsize=(20,20))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## SA1 Areas

# %% [markdown]
# We will repeat the above process for SA1 areas

# %%
sa1_regional = sa1.loc[sa1['SA3_NAME16'].isin(['Tweed Valley', 'Newcastle', 'Maitland', 'Wollongong', 'Albury']), :]

# %%
sa1_regional
# Out:
#        SA1_MAIN16 SA1_7DIG16 SA2_MAIN16 SA2_5DIG16         SA2_NAME16  \
# 2993  10602111401    1111401  106021114      11114           Maitland
# 2994  10602111402    1111402  106021114      11114           Maitland
# 2995  10602111403    1111403  106021114      11114           Maitland
# 2996  10602111404    1111404  106021114      11114           Maitland
# 2997  10602111405    1111405  106021114      11114           Maitland
# ...           ...        ...        ...        ...                ...
# 7179  11203155217    1155217  112031552      11552  Tweed Heads South
# 7180  11203155218    1155218  112031552      11552  Tweed Heads South
# 7181  11203155219    1155219  112031552      11552  Tweed Heads South
# 7182  11203155220    1155220  112031552      11552  Tweed Heads South
# 7183  11203155221    1155221  112031552      11552  Tweed Heads South
#
#      SA3_CODE16    SA3_NAME16 SA4_CODE16                   SA4_NAME16  \
# ...

# %%
sa1_regional.plot()
# Out:
# <AxesSubplot:>

# %%
sa1_regional.count()
# Out:
# SA1_MAIN16    1277
# SA1_7DIG16    1277
# SA2_MAIN16    1277
# SA2_5DIG16    1277
# SA2_NAME16    1277
# SA3_CODE16    1277
# SA3_NAME16    1277
# SA4_CODE16    1277
# SA4_NAME16    1277
# GCC_CODE16    1277
# GCC_NAME16    1277
# STE_CODE16    1277
# STE_NAME16    1277
# AREASQKM16    1277
# geometry      1277
# dtype: int64

# %%
sa1_capital = sa1.loc[sa1['GCC_NAME16']=='Greater Sydney']

# %%
sa1_capital
# Out:
#         SA1_MAIN16 SA1_7DIG16 SA2_MAIN16 SA2_5DIG16                SA2_NAME16  \
# 631    10201102801    1102801  102011028      11028  Avoca Beach - Copacabana
# 632    10201102802    1102802  102011028      11028  Avoca Beach - Copacabana
# 633    10201102803    1102803  102011028      11028  Avoca Beach - Copacabana
# 634    10201102804    1102804  102011028      11028  Avoca Beach - Copacabana
# 635    10201102805    1102805  102011028      11028  Avoca Beach - Copacabana
# ...            ...        ...        ...        ...                       ...
# 18390  12802160906    1160906  128021609      11609          Woronora Heights
# 18391  12802160907    1160907  128021609      11609          Woronora Heights
# 18392  12802160908    1160908  128021609      11609          Woronora Heights
# 18393  12802160909    1160909  128021609      11609          Woronora Heights
# 18394  12802160910    1160910  128021609      11609          Woronora Heights
#
# ...

# %%
sa1_capital.plot(figsize=(20,20))
# Out:
# <AxesSubplot:>

# %%
sa1_capital.count()
# Out:
# SA1_MAIN16    11171
# SA1_7DIG16    11171
# SA2_MAIN16    11171
# SA2_5DIG16    11171
# SA2_NAME16    11171
# SA3_CODE16    11171
# SA3_NAME16    11171
# SA4_CODE16    11171
# SA4_NAME16    11171
# GCC_CODE16    11171
# GCC_NAME16    11171
# STE_CODE16    11171
# STE_NAME16    11171
# AREASQKM16    11171
# geometry      11171
# dtype: int64

# %%
sa1_all = pd.concat([sa1_regional, sa1_capital])
sa1_all.count()
# Out:
# SA1_MAIN16    12448
# SA1_7DIG16    12448
# SA2_MAIN16    12448
# SA2_5DIG16    12448
# SA2_NAME16    12448
# SA3_CODE16    12448
# SA3_NAME16    12448
# SA4_CODE16    12448
# SA4_NAME16    12448
# GCC_CODE16    12448
# GCC_NAME16    12448
# STE_CODE16    12448
# STE_NAME16    12448
# AREASQKM16    12448
# geometry      12448
# dtype: int64

# %%
sa1_all
# Out:
#         SA1_MAIN16 SA1_7DIG16 SA2_MAIN16 SA2_5DIG16        SA2_NAME16  \
# 2993   10602111401    1111401  106021114      11114          Maitland
# 2994   10602111402    1111402  106021114      11114          Maitland
# 2995   10602111403    1111403  106021114      11114          Maitland
# 2996   10602111404    1111404  106021114      11114          Maitland
# 2997   10602111405    1111405  106021114      11114          Maitland
# ...            ...        ...        ...        ...               ...
# 18390  12802160906    1160906  128021609      11609  Woronora Heights
# 18391  12802160907    1160907  128021609      11609  Woronora Heights
# 18392  12802160908    1160908  128021609      11609  Woronora Heights
# 18393  12802160909    1160909  128021609      11609  Woronora Heights
# 18394  12802160910    1160910  128021609      11609  Woronora Heights
#
#       SA3_CODE16                      SA3_NAME16 SA4_CODE16  \
# 2993       10602                        Maitland        106
# ...

# %%
sa1_all.plot(figsize=(20,20))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Export shapefiles

# %%
sa2_all.to_file("Study Area/sa2_nsw.shp")

# %%
sa1_all.to_file("Study Area/sa1_nsw.shp")

# %% [markdown]
# ## Boundaries
#
# Dissolving geometries to obtain boundaries of the study areas. These will be helpful when extracting raster data and pointclouds.

# %%
sa2_diss = sa2_all.dissolve()

# %%
sa2_diss
# Out:
#                                             geometry SA2_MAIN16 SA2_5DIG16  \
# 0  MULTIPOLYGON (((146.84610 -36.08631, 146.84537...  106021114      11114
#
#   SA2_NAME16 SA3_CODE16 SA3_NAME16 SA4_CODE16                   SA4_NAME16  \
# 0   Maitland      10602   Maitland        106  Hunter Valley exc Newcastle
#
#   GCC_CODE16   GCC_NAME16 STE_CODE16       STE_NAME16  AREASQKM16
# 0      1RNSW  Rest of NSW          1  New South Wales      32.079

# %%
sa2_diss.plot(figsize=(20,20))
# Out:
# <AxesSubplot:>

# %%
sa2_diss.to_file("Study Area/boundaries.shp")
