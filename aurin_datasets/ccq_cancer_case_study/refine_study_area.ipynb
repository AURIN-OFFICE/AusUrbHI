# %%
# use pandas to open csv file and show head
import pandas as pd

file_name = "datasource-AU_Govt_ABS-UoM_AURIN_DB_3_sa2_seifa_irsd_2016.csv"
df = pd.read_csv(f"../../_data/{file_name}")
print(df.columns)
# Out:
# Index(['FID', 'sa2_main16', 'sa2_name16', 'usual_res_pop', 'irsd_score',
#        'national_rank', 'national_decile', 'national_percentile', 'state',
#        'state_rank', 'state_decile', 'state_percentile',
#        'min_sa1_score_in_area', 'max_sa1_score_in_area',
#        'ur_pop_wthout_sa1_level_score_pc', 'wkb_geometry'],
#       dtype='object')

# %%
file_name = "datasource-TUA_PHIDU-UoM_AURIN_DB_1_phidu_estimates_risk_factors_adults_pha_2017_18.csv"
df = pd.read_csv(f"../../_data/{file_name}")
print(df.columns)
# Out:
# Index(['FID', 'fid', 'pha_code', 'pha_name',
#        'estmd_nmbr_mls_agd_18_yrs_hg_psychlg_dstr_bsd_kslr_10_scle_k10',
#        'estmd_nmbr_mls_agd_18_yrs_hg_psychlg_dstr_bsd_kslr_10_scle__11',
#        'estmd_nmbr_mls_agd_18_yrs_hg_psychlg_dstr_bsd_kslr_10_scle__12',
#        'estmd_nmbr_mls_agd_18_yrs_hg_psychlg_dstr_bsd_kslr_10_scle__13',
#        'estmd_nmbr_mls_agd_18_yrs_hg_psychlg_dstr_bsd_kslr_10_scle__14',
#        'estmd_nmbr_mls_agd_18_yrs_hg_psychlg_dstr_bsd_kslr_10_scle__15',
#        ...
#        'estmd_nmbr_ple_agd_18_yrs_adqte_frt_intke_mdl_estm_2017_rmse',
#        'estmd_pltn_agd_18_yrs_undrtk_lw_exrcs_prvs_wk_mdl_estm_2017_nmb',
#        'estmd_pltn_agd_18_yrs_undrtk_lw_exrcs_prvs_wk_mdl_estm_2017_asr',
#        'estmd_pltn_agd_18_yrs_undrtk_lw_exrcs_prvs_wk_mdl_estm_2017_a_0',
#        'estmd_pltn_agd_18_yrs_undrtk_lw_exrcs_prvs_wk_mdl_estm_2017_a_1',
#        'estmd_pltn_agd_18_yrs_undrtk_lw_exrcs_prvs_wk_mdl_estm_2017_sr',
# ...

# %%
print(df.head())
# Out:
#                                                  FID  fid  pha_code
# 0  phidu_estimates_risk_factors_adults_pha_2017_18.1    1     10283  \
# 1  phidu_estimates_risk_factors_adults_pha_2017_18.2    2     10225
# 2  phidu_estimates_risk_factors_adults_pha_2017_18.3    3     10226
# 3  phidu_estimates_risk_factors_adults_pha_2017_18.4    4     10249
# 4  phidu_estimates_risk_factors_adults_pha_2017_18.5    5     10250
#
#                                      pha_name
# 0                          Adamstown - Kotara  \
# 1                Albion Park - Macquarie Pass
# 2  Albion Park Rail/ Shellharbour - Oak Flats
# 3                               Albury - East
# 4                   Albury - North/ Lavington
#
#    estmd_nmbr_mls_agd_18_yrs_hg_psychlg_dstr_bsd_kslr_10_scle_k10
# 0                                                           604.0  \
# 1                                                           651.0
# 2                                                           798.0
# ...
